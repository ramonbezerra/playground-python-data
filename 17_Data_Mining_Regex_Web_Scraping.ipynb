# %%
import re

# %%
data = "Lorem Ipsum is simply dummy text of the printing email@email.com.br at 18h - 19h typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type mary@mailing.com and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets joe@mail.com containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."

# %%
matches = re.findall(r"[0-9]+h", data)
matches
# Out:
# ['18h', '19h']

# %%
data = "Code review concluído no dia 31/05/2021 e Merge feito no dia 23/07/2021 e Deploy feito no dia 12/10/2022"

# %%
matches = re.findall(r"(\d{2}\/(0[456]|0[789])\/\d{4})", data)
matches
# Out:
# [('31/05/2021', '05'), ('23/07/2021', '07')]

# %%
matches = re.findall(r"[\w\.-]+@[\w\.-]+\.[\w]{2,3}", data) # ([a-z.0-9]+@[a-z.0-9]+)
matches
# Out:
# ['email@email.com.br', 'mary@mailing.com', 'joe@mail.com']

# %%
url = "https://www.python.org/blogs/"

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
if page.status_code == 200:
    soup = BeautifulSoup(page.content, "html.parser")
    print(soup.prettify())
else:
    print("Error")
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" dir="ltr" lang="en">
#  <!--<![endif]-->
#  <head>
#   <!-- Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-TF35YF9CVH">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#       gtag('config', 'G-TF35YF9CVH');
#   </script>
#   <!-- Plausible.io analytics -->
#   <script data-domain="python.org" defer="" src="https://plausible.io/js/script.js">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# ...

# %%
news = soup.find("ul", class_="list-recent-posts")
latest_news = news.find_all("h3")
latest_news
# Out:
# [<h3 class="event-title"><a href="https://pyfound.blogspot.com/2025/03/dsa-thomas-wouters.html">PSF Distinguished Service Award Granted to Thomas Wouters</a></h3>,
#  <h3 class="event-title"><a href="https://pyfound.blogspot.com/2025/03/dsa-van-lindberg.html">PSF Distinguished Service Award Granted to Van Lindberg</a></h3>,
#  <h3 class="event-title"><a href="https://pyfound.blogspot.com/2025/03/psf-dsa-ewa-jodlowska.html">PSF Distinguished Service Award Granted to Ewa Jodlowska</a></h3>,
#  <h3 class="event-title"><a href="https://pyfound.blogspot.com/2025/03/announcing-python-software-foundation.html">Announcing Python Software Foundation Fellow Members for Q4 2024! 🎉</a></h3>,
#  <h3 class="event-title"><a href="https://pyfound.blogspot.com/2025/02/where-is-psf-2025-edition.html">Where is the PSF? 2025 Edition</a></h3>]

# %%
for news in latest_news:
    link = news.find("a")["href"]
    print(f"Artigo: {news.text}\nLink: {link}\n")
# Out:
# Artigo: PSF Distinguished Service Award Granted to Thomas Wouters
# Link: https://pyfound.blogspot.com/2025/03/dsa-thomas-wouters.html
#
# Artigo: PSF Distinguished Service Award Granted to Van Lindberg
# Link: https://pyfound.blogspot.com/2025/03/dsa-van-lindberg.html
#
# Artigo: PSF Distinguished Service Award Granted to Ewa Jodlowska
# Link: https://pyfound.blogspot.com/2025/03/psf-dsa-ewa-jodlowska.html
#
# Artigo: Announcing Python Software Foundation Fellow Members for Q4 2024! 🎉
# Link: https://pyfound.blogspot.com/2025/03/announcing-python-software-foundation.html
#
# Artigo: Where is the PSF? 2025 Edition
# Link: https://pyfound.blogspot.com/2025/02/where-is-psf-2025-edition.html
